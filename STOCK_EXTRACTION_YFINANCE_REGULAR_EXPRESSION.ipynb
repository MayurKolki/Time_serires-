# %% [markdown]
# # STOCK_EXTRACTION_YFINANCE_REGULAR_EXPRESSION _REQUEST

# %%
import re
import json 
import csv 
from io import StringIO
from bs4 import BeautifulSoup
import requests

# %%
url_st = "https://in.finance.yahoo.com/quote/RELIANCE.NS/key-statistics?p=RELIANCE.NS"
url_fin = "https://in.finance.yahoo.com/quote/RELIANCE.NS/financials?p=RELIANCE.NS"
url_pro = "https://in.finance.yahoo.com/quote/RELIANCE.NS/profile?p=RELIANCE.NS"

# %%
stock = "https://query1.finance.yahoo.com/v7/finance/download/RELIANCE.NS?period1=1594220310&period2=1625756310&interval=1d&events=history&includeAdjustedClose=true"

# %%
response = requests.get(stock)

# %%
response.text
# Out:
# 'Date,Open,High,Low,Close,Adj Close,Volume\n2020-07-08,1824.050049,1834.949951,1790.000000,1798.000000,1792.234497,12093186\n2020-07-09,1809.000000,1835.000000,1786.250000,1824.250000,1818.400391,16807336\n2020-07-10,1828.500000,1884.599976,1824.250000,1878.050049,1872.027832,20195218\n2020-07-13,1903.349976,1947.699951,1900.000000,1935.000000,1928.795166,32124262\n2020-07-14,1934.000000,1941.699951,1887.300049,1917.000000,1910.852905,31073305\n2020-07-15,1937.949951,1978.800049,1798.000000,1844.000000,1838.087036,64457578\n2020-07-16,1847.000000,1869.000000,1812.449951,1843.400024,1837.489014,28133826\n2020-07-17,1845.000000,1920.000000,1838.000000,1911.699951,1905.569824,22948894\n2020-07-20,1917.800049,1932.000000,1899.650024,1919.900024,1913.743652,16887635\n2020-07-21,1939.000000,1977.000000,1936.500000,1971.550049,1965.228027,19463004\n2020-07-22,1983.000000,2010.000000,1960.699951,2004.000000,1997.573975,27584518\n2020-07-23,2003.949951,2079.699951,1991.349976,2057.800049,2051
# ...

# %%
stock = "https://query1.finance.yahoo.com/v7/finance/download/RELIANCE.NS{}?"

# %%
params ={
    'period1':'1594220310'
    'period2':'1625756310'
    'interval':'1d'
     #'events':'history'
}

# %%
params ={
    'range' : '5y',
    'interval':'1d'
    #'events' : 'history'
}

# %%
response = requests.get(stock.format(stock),params=params)

# %%
response.text

# %%
file = StringIO(response.text)
reader = csv.reader(file)
data = list(reader)
for row in data[:5]:
    print(row)
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# ['2020-07-08', '1824.050049', '1834.949951', '1790.000000', '1798.000000', '1792.234497', '12093186']
# ['2020-07-09', '1809.000000', '1835.000000', '1786.250000', '1824.250000', '1818.400391', '16807336']
# ['2020-07-10', '1828.500000', '1884.599976', '1824.250000', '1878.050049', '1872.027832', '20195218']
# ['2020-07-13', '1903.349976', '1947.699951', '1900.000000', '1935.000000', '1928.795166', '32124262']

# %%
data
# Out:
# [['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'],
#  ['2020-07-08',
#   '1824.050049',
#   '1834.949951',
#   '1790.000000',
#   '1798.000000',
#   '1792.234497',
#   '12093186'],
#  ['2020-07-09',
#   '1809.000000',
#   '1835.000000',
#   '1786.250000',
#   '1824.250000',
#   '1818.400391',
#   '16807336'],
#  ['2020-07-10',
#   '1828.500000',
#   '1884.599976',
#   '1824.250000',
#   '1878.050049',
#   '1872.027832',
#   '20195218'],
#  ['2020-07-13',
#   '1903.349976',
#   '1947.699951',
#   '1900.000000',
#   '1935.000000',
#   '1928.795166',
#   '32124262'],
#  ['2020-07-14',
#   '1934.000000',
#   '1941.699951',
#   '1887.300049',
#   '1917.000000',
#   '1910.852905',
#   '31073305'],
#  ['2020-07-15',
#   '1937.949951',
#   '1978.800049',
#   '1798.000000',
#   '1844.000000',
#   '1838.087036',
#   '64457578'],
#  ['2020-07-16',
#   '1847.000000',
#   '1869.000000',
#   '1812.449951',
#   '1843.400024',
#   '1837.489014',
#   '28133826'],
#  ['2020-07-17',
# ...

# %%
################################

# %% [markdown]
# # AMAZON WEB SCRAPPER

# %% [markdown]
# # requirements
#
# Selenium
#
# beautifulsoap

# %%
import csv 
from bs4 import BeautifulSoup

# %%
#chrome & firefox
from selenium import webdriver

# %%
#microsoft edge
from msedge.selenium_tools import Edge ,EdgeOptions

# %%
# !pip install selenium

# %%
###############################

# %%
# !pip install autoscrapper
# Out:
# ERROR: Could not find a version that satisfies the requirement autoscrapper
# ERROR: No matching distribution found for autoscrapper

# %%
web_scrap_risk_analysis
